# %%
# %matplotlib inline

# %% [markdown]
# Get sleep statistics
# ====================
#
# Get sleep statictics such as sleep stages duration, duration of the hypnogram.

# %%
from visbrain.io import download_file, get_sleep_stats

# %% [markdown]
# Hypnogram data
# ##############################################################################
#  Download a hypnogram example

# %%
path_to_hypno = download_file("s101_jbe.hyp", astype='example_data')
# Out:
# Downloading /Users/qdo/visbrain_data/example_data/s101_jbe.hyp
# Folder /Users/qdo/visbrain_data/example_data created
# STATUS : 100.0% 49152 / 45660

# %% [markdown]
# Get sleep statistics
# ##############################################################################
#  Sleep statistics are going to be printed in the terminal and then saved in a
#  `my_stats.csv`

# %%
get_sleep_stats(path_to_hypno, output_file='my_stats.csv')
# Out:
# Hypnogram successfully loaded (/Users/qdo/visbrain_data/example_data/s101_jbe.hyp)
# SLEEP STATS
# ===========
# TIB 	 360.1666666666667
# TDT 	 359.98333333333335
# Art 	 39.5
# W 	 19.166666666666668
# N1 	 12.0
# N2 	 115.5
# N3 	 114.5
# REM 	 59.5
# LatN1 	 4.0
# LatN2 	 7.0
# LatN3 	 9.0
# LatREM 	 66.0
# SPT 	 355.98333333333335
# WASO 	 15.0
# TST 	 340.98333333333335
# SE 	 94.72
# Units 	 minutes
# File 	 /Users/qdo/visbrain_data/example_data/s101_jbe.hyp
# ===========
# CSV file saved to: my_stats.csv

# %%
from visbrain.io import write_fig_hyp, read_hypno, download_file
import matplotlib.pyplot as plt

grid = True     # display the grid
ascolor = True  # plt as color or in black and white
file = None     # Name of the file to be saved example : 'myfile.png'
path_to_hypno = download_file("s101_jbe.hyp", astype='example_data')
data, sf = read_hypno(path_to_hypno)

write_fig_hyp(data, sf, grid=grid, ascolor=ascolor, file=file)
plt.show()
# Out:
# File already dowloaded (/Users/qdo/visbrain_data/example_data/s101_jbe.hyp).
# Hypnogram successfully loaded (/Users/qdo/visbrain_data/example_data/s101_jbe.hyp)
# /Users/qdo/opt/anaconda3/lib/python3.7/site-packages/visbrain/io/write_image.py:104: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   linewidth=lw)

# %%
write_fig_hyp(data, sf, grid=grid, ascolor=ascolor, file=file)
plt.show()
